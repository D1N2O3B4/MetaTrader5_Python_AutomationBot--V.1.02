# %%
import MetaTrader5 as mt5
from datetime import datetime
import pandas as pd

# %% [markdown]
# IMPORT TICK RANGE DATA

# %%
mt5.initialize()
# Out:
# True

# %%
from_date = datetime(2022,1,1)
to_date = datetime(2022,2,2)

tick_range = mt5.copy_ticks_range("EURUSD",from_date,to_date,mt5.COPY_TICKS_ALL)

df_tick_range = pd.DataFrame(tick_range)

df_tick_range["time"] = pd.to_datetime(df_tick_range["time"],unit="s")

df_tick_range
# Out:
#                        time      bid      ask  last  volume       time_msc  \
# 0       2022-01-03 00:05:00  1.13693  1.13758   0.0       0  1641168300139
# 1       2022-01-03 00:05:01  1.13689  1.13754   0.0       0  1641168301856
# 2       2022-01-03 00:05:09  1.13688  1.13753   0.0       0  1641168309218
# 3       2022-01-03 00:05:11  1.13689  1.13754   0.0       0  1641168311268
# 4       2022-01-03 00:05:26  1.13688  1.13753   0.0       0  1641168326276
# ...                     ...      ...      ...   ...     ...            ...
# 1382696 2022-02-01 23:59:50  1.12725  1.12740   0.0       0  1643759990907
# 1382697 2022-02-01 23:59:56  1.12722  1.12731   0.0       0  1643759996222
# 1382698 2022-02-01 23:59:56  1.12720  1.12731   0.0       0  1643759996261
# 1382699 2022-02-01 23:59:58  1.12717  1.12732   0.0       0  1643759998138
# 1382700 2022-02-01 23:59:59  1.12718  1.12733   0.0       0  1643759999409
#
#          flags  volume_real
# 0          134          0.0
# ...
